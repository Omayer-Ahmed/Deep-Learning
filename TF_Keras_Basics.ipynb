# %% [markdown]
# <a href="https://colab.research.google.com/github/Omayer-Ahmed/Deep-Learning/blob/main/TF_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3ade7cf9-c729-44b6-b1f9-2623f24d264a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ade7cf9-c729-44b6-b1f9-2623f24d264a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df_csv=pd.read_csv('diabetes.csv')

# %%
df_csv.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import seaborn as sb
df_csv['Outcome'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
x=df_csv.iloc[:,0:8]

# %%
x.tail(2)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 766                     0.349   47
# 767                     0.315   23

# %%
y=df_csv.iloc[:,8:9]

# %%
y.head(3)
# Out:
#    Outcome
# 0        1
# 1        0
# 2        1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (614, 8)

# %%
y_test.shape
# Out:
# (154, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(12,input_dim=8,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
#compiling model
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#fitting model
model.fit(x_train,y_train,epochs=150,batch_size=10)
# Out:
# Epoch 1/150
# 62/62 [==============================] - 1s 2ms/step - loss: 2.5217 - accuracy: 0.5896
# Epoch 2/150
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4368 - accuracy: 0.5977
# Epoch 3/150
# 62/62 [==============================] - 0s 2ms/step - loss: 1.2186 - accuracy: 0.6091
# Epoch 4/150
# 62/62 [==============================] - 0s 2ms/step - loss: 1.0651 - accuracy: 0.6091
# Epoch 5/150
# 62/62 [==============================] - 0s 2ms/step - loss: 1.0105 - accuracy: 0.6124
# Epoch 6/150
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8662 - accuracy: 0.6466
# Epoch 7/150
# 62/62 [==============================] - 0s 2ms/step - loss: 0.8251 - accuracy: 0.6156
# Epoch 8/150
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7728 - accuracy: 0.6319
# Epoch 9/150
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7772 - accuracy: 0.6254
# Epoch 10/150
# ...

# %%
'''loss_df=pd.DataFrame(model.history.history)
loss_df'''
# Out:
# 'loss_df=pd.DataFrame(model.history.history)\nloss_df'

# %%
#loss_df.plot()

# %%
#train accuracy
model.evaluate(x_train,y_train)
# Out:
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.7638
# [0.5038660168647766, 0.7638436555862427]

# %%
model.evaluate(x_test,y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5251 - accuracy: 0.7273
# [0.525070071220398, 0.7272727489471436]

# %%
import numpy as np

# Assuming model is your trained neural network model
y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6168831168831169
